# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pingouin as pg
import plot_likert as pl

plt.rcParams["figure.figsize"]=13,13

ATT_FOLDER = "../data/attitudes"
LS_FOLDER = "../data/ls"

CONTEXTS = ["Relaxing", "Commuting", "Partying", "Running","Shopping",
            "Sleeping", "Studying", "Working"]
TRACK_FEATS = ["Tempo", "Danceability", "Acousticness", "Instrumentalness"]
ARTIST_FEATS = ["Gender", "Skin", "Origin", "Age"]
ROUNDS =  ["00", "01", "02", "03"]
ROUNDS_LAB = ['Pre', '1 week', "2 week", "3 week"]
GROUPS = ["HD", "LD"]
SESSION1 = [str(x).zfill(2) for x in range(1,6)]
SESSION2 = [str(x).zfill(2) for x in range(6,11)]
SESSION3 = [str(x).zfill(2) for x in range(11,16)]
SESSIONS = [SESSION1, SESSION2, SESSION3]

# %%
from analyze_attitudes import *

# %%
df_join_att = import_data("scores")
df_join_att.d_score = - df_join_att.d_score
df_join_cntx = import_data("cntx")
df_join_ls = import_ls_data()
df_join_ls = scale_ls_data(df_join_ls)

# %%
plot_scores(df_join_att)
# Out:
# /home/lorenzoporcaro/.virtualenvs/longterm/lib/python3.8/site-packages/pingouin/regression.py:432: RuntimeWarning: divide by zero encountered in double_scalars
#   r2 = 1 - ss_res / ss_wtot

# %%
plot_correlation(df_join_att)
# Out:
# HD d_score
# |        Pre |    Week 1 |    Week 2 |    Week 3 |     Week 4 |
# |------------|-----------|-----------|-----------|------------|
# |  1         |  0.68658  | -0.472494 |  0.931991 | -0.0203239 |
# |  0.68658   |  1        | -0.163385 |  0.902012 |  0.705998  |
# | -0.472494  | -0.163385 |  1        | -0.392553 |  0.346584  |
# |  0.931991  |  0.902012 | -0.392553 |  1        |  0.332886  |
# | -0.0203239 |  0.705998 |  0.346584 |  0.332886 |  1         |
# LD d_score
# |       Pre |    Week 1 |     Week 2 |   Week 3 |   Week 4 |
# |-----------|-----------|------------|----------|----------|
# |  1        | 0.93859   | -0.315774  | 0.607206 | 0.142339 |
# |  0.93859  | 1         |  0.0246394 | 0.757967 | 0.401216 |
# | -0.315774 | 0.0246394 |  1         | 0.207747 | 0.791144 |
# |  0.607206 | 0.757967  |  0.207747  | 1        | 0.153635 |
# |  0.142339 | 0.401216  |  0.791144  | 0.153635 | 1        |
# HD o_score
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.980196 | 0.802181 | 0.802181 | 0.980196 |
# | 0.980196 | 1        | 0.904534 | 0.904534 | 1        |
# | 0.802181 | 0.904534 | 1        | 1        | 0.904534 |
# | 0.802181 | 0.904534 | 1        | 1        | 0.904534 |
# | 0.980196 | 1        | 0.904534 | 0.904534 | 1        |
# LD o_score
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.978839 | 0.942908 | 0.970143 | 0.942908 |
# | 0.978839 | 1        | 0.946256 | 0.998115 | 0.946256 |
# | 0.942908 | 0.946256 | 1        | 0.957841 | 1        |
# | 0.970143 | 0.998115 | 0.957841 | 1        | 0.957841 |
# | 0.942908 | 0.946256 | 1        | 0.957841 | 1        |

# %%
plot_cntx(df_join_cntx)
# Out:
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:238: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Disagree', '', '', '', 'Agree'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:277: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Slow', '', '', '', 'Fast'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:279: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:279: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:279: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:318: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Female', '', '', '', 'Male'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:320: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['White', '', '', '', 'Black'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:322: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low-income', '', '', '', 'High-income'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<40', '', '', '', '>40'])
# ['Relaxing', 'Commuting', 'Partying', 'Running', 'Shopping', 'Sleeping', 'Studying', 'Working']
# HD
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.667119 | 0.761194 | 0.760678 | 0.575682 |
# | 0.667119 | 1        | 0.74648  | 0.784531 | 0.688525 |
# | 0.761194 | 0.74648  | 1        | 0.859481 | 0.719933 |
# | 0.760678 | 0.784531 | 0.859481 | 1        | 0.735365 |
# | 0.575682 | 0.688525 | 0.719933 | 0.735365 | 1        |
# LD
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.696934 | 0.560603 | 0.658269 | 0.691416 |
# | 0.696934 | 1        | 0.709758 | 0.797985 | 0.767565 |
# | 0.560603 | 0.709758 | 1        | 0.738726 | 0.622859 |
# | 0.658269 | 0.797985 | 0.738726 | 1        | 0.88346  |
# | 0.691416 | 0.767565 | 0.622859 | 0.88346  | 1        |
#
# ['Tempo', 'Danceability', 'Acousticness', 'Instrumentalness']
# HD
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.785589 | 0.831171 | 0.890256 | 0.670182 |
# | 0.785589 | 1        | 0.869618 | 0.844403 | 0.82536  |
# | 0.831171 | 0.869618 | 1        | 0.841875 | 0.719021 |
# | 0.890256 | 0.844403 | 0.841875 | 1        | 0.769587 |
# | 0.670182 | 0.82536  | 0.719021 | 0.769587 | 1        |
# LD
# /home/lorenzoporcaro/.virtualenvs/longterm/lib/python3.8/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.533024 | 0.903263 | 0.868538 | 0.925339 |
# | 0.533024 | 1        | 0.70285  | 0.50114  | 0.823437 |
# | 0.903263 | 0.70285  | 1        | 0.856556 | 0.921343 |
# | 0.868538 | 0.50114  | 0.856556 | 1        | 0.859127 |
# | 0.925339 | 0.823437 | 0.921343 | 0.859127 | 1        |
#
# ['Gender', 'Skin', 'Origin', 'Age']
# HD
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.956796 | 0.949114 | 0.65291  | 0.857034 |
# | 0.956796 | 1        | 0.976265 | 0.654083 | 0.926249 |
# | 0.949114 | 0.976265 | 1        | 0.777778 | 0.987417 |
# | 0.65291  | 0.654083 | 0.777778 | 1        | 0.894338 |
# | 0.857034 | 0.926249 | 0.987417 | 0.894338 | 1        |
# LD
# |      Pre |   Week 1 |   Week 2 |   Week 3 |   Week 4 |
# |----------|----------|----------|----------|----------|
# | 1        | 0.917339 | 0.766984 | 0.846832 | 0.846832 |
# | 0.917339 | 1        | 0.880901 | 0.824595 | 0.824595 |
# | 0.766984 | 0.880901 | 1        | 0.857538 | 0.857538 |
# | 0.846832 | 0.824595 | 0.857538 | 1        | 1        |
# | 0.846832 | 0.824595 | 0.857538 | 1        | 1        |

# %%
#plot_mixed(df_join_att, df_join_ls)

# %%
plot_ls(df_join_ls)
