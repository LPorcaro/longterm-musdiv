# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pingouin as pg
import plot_likert as pl

plt.rcParams["figure.figsize"]=13,13

ATT_FOLDER = "../data/attitudes"
LS_FOLDER = "../data/ls"

CONTEXTS = ["Relaxing", "Commuting", "Partying", "Running","Shopping",
            "Sleeping", "Studying", "Working"]
TRACK_FEATS = ["Tempo", "Danceability", "Acousticness", "Instrumentalness"]
ARTIST_FEATS = ["Gender", "Skin", "Origin", "Age"]
ROUNDS =  ["00", "01", "02", "03"]
ROUNDS_LAB = ['Pre', '1 week', "2 week", "3 week"]
GROUPS = ["g1", "g2"]
SESSION1 = [str(x).zfill(2) for x in range(1,6)]
SESSION2 = [str(x).zfill(2) for x in range(6,11)]
SESSION3 = [str(x).zfill(2) for x in range(11,16)]
SESSIONS = [SESSION1, SESSION2, SESSION3]

# %%
from analyze_attitudes import *

# %%
df_join_att = import_data("scores")
df_join_att.d_score = - df_join_att.d_score
df_join_cntx = import_data("cntx")
df_join_ls = import_ls_data()
df_join_ls = scale_ls_data(df_join_ls)

# %%
plot_scores(df_join_att)
# Out:
# /home/lorenzoporcaro/.virtualenvs/longterm/lib/python3.8/site-packages/pingouin/regression.py:432: RuntimeWarning: invalid value encountered in double_scalars
#   r2 = 1 - ss_res / ss_wtot
# /home/lorenzoporcaro/.virtualenvs/longterm/lib/python3.8/site-packages/pingouin/regression.py:443: RuntimeWarning: divide by zero encountered in true_divide
#   T = coef / beta_se

# %%
plot_correlation(df_join_att)
# Out:
# g1 d_score
# [[ 1.          0.68658046 -0.47249438  0.93199107]
#  [ 0.68658046  1.         -0.16338452  0.90201175]
#  [-0.47249438 -0.16338452  1.         -0.39255253]
#  [ 0.93199107  0.90201175 -0.39255253  1.        ]]
# g2 d_score
# [[ 1.          0.93858982 -0.3157739   0.60720553]
#  [ 0.93858982  1.          0.02463937  0.75796718]
#  [-0.3157739   0.02463937  1.          0.20774654]
#  [ 0.60720553  0.75796718  0.20774654  1.        ]]
# g1 o_score
# [[1.         0.98019606 0.80218063 0.80218063]
#  [0.98019606 1.         0.90453403 0.90453403]
#  [0.80218063 0.90453403 1.         1.        ]
#  [0.80218063 0.90453403 1.         1.        ]]
# g2 o_score
# [[1.         0.97883892 0.94290807 0.9701425 ]
#  [0.97883892 1.         0.94625552 0.99811498]
#  [0.94290807 0.94625552 1.         0.95784149]
#  [0.9701425  0.99811498 0.95784149 1.        ]]

# %%
plot_cntx(df_join_cntx)
# Out:
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:233: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Disagree', '', '', '', 'Agree'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:273: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Slow', '', '', '', 'Fast'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:275: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:275: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:275: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low', '', '', '', 'High'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:315: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Female', '', '', '', 'Male'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:317: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['White', '', '', '', 'Black'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:319: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['Low-income', '', '', '', 'High-income'])
# /home/lorenzoporcaro/Workspace/longterm-musdiv/src/analyze_attitudes.py:321: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['<40', '', '', '', '>40'])

# %%
plot_mixed(df_join_att, df_join_ls)

# %%
plot_ls(df_join_ls)
